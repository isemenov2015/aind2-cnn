# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               2097664
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 2,168,362
# Trainable params: 2,168,362
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=64, epochs=30,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/30
# Epoch 00000: val_loss improved from inf to 1.40620, saving model to model.weights.best.hdf5
# 16s - loss: 1.6407 - acc: 0.4061 - val_loss: 1.4062 - val_acc: 0.4940
# Epoch 2/30
# Epoch 00001: val_loss improved from 1.40620 to 1.11658, saving model to model.weights.best.hdf5
# 15s - loss: 1.1787 - acc: 0.5820 - val_loss: 1.1166 - val_acc: 0.6102
# Epoch 3/30
# Epoch 00002: val_loss improved from 1.11658 to 0.91431, saving model to model.weights.best.hdf5
# 15s - loss: 0.9854 - acc: 0.6564 - val_loss: 0.9143 - val_acc: 0.6824
# Epoch 4/30
# Epoch 00003: val_loss did not improve
# 15s - loss: 0.8857 - acc: 0.6913 - val_loss: 1.6150 - val_acc: 0.4934
# Epoch 5/30
# Epoch 00004: val_loss improved from 0.91431 to 0.89172, saving model to model.weights.best.hdf5
# 15s - loss: 0.8201 - acc: 0.7162 - val_loss: 0.8917 - val_acc: 0.7106
# Epoch 6/30
# Epoch 00005: val_loss did not improve
# 15s - loss: 0.7837 - acc: 0.7320 - val_loss: 0.9264 - val_acc: 0.7292
# Epoch 7/30
# Epoch 00006: val_loss improved from 0.89172 to 0.84622, saving model to model.weights.best.hdf5
# 15s - loss: 0.7558 - acc: 0.7418 - val_loss: 0.8462 - val_acc: 0.7224
# Epoch 8/30
# Epoch 00007: val_loss improved from 0.84622 to 0.80129, saving model to model.weights.best.hdf5
# 15s - loss: 0.7410 - acc: 0.7499 - val_loss: 0.8013 - val_acc: 0.7416
# Epoch 9/30
# Epoch 00008: val_loss did not improve
# 15s - loss: 0.7394 - acc: 0.7535 - val_loss: 1.6196 - val_acc: 0.5724
# Epoch 10/30
# Epoch 00009: val_loss improved from 0.80129 to 0.79136, saving model to model.weights.best.hdf5
# 15s - loss: 0.7315 - acc: 0.7589 - val_loss: 0.7914 - val_acc: 0.7354
# Epoch 11/30
# Epoch 00010: val_loss did not improve
# 15s - loss: 0.7309 - acc: 0.7575 - val_loss: 0.9838 - val_acc: 0.7194
# Epoch 12/30
# Epoch 00011: val_loss did not improve
# 15s - loss: 0.7442 - acc: 0.7564 - val_loss: 0.9667 - val_acc: 0.6892
# Epoch 13/30
# Epoch 00012: val_loss did not improve
# 15s - loss: 0.7449 - acc: 0.7581 - val_loss: 1.3781 - val_acc: 0.5642
# Epoch 14/30
# Epoch 00013: val_loss improved from 0.79136 to 0.75124, saving model to model.weights.best.hdf5
# 15s - loss: 0.7508 - acc: 0.7569 - val_loss: 0.7512 - val_acc: 0.7658
# Epoch 15/30
# Epoch 00014: val_loss did not improve
# 15s - loss: 0.7589 - acc: 0.7514 - val_loss: 1.3543 - val_acc: 0.6996
# Epoch 16/30
# Epoch 00015: val_loss did not improve
# 15s - loss: 0.7685 - acc: 0.7553 - val_loss: 1.1501 - val_acc: 0.6644
# Epoch 17/30
# Epoch 00016: val_loss did not improve
# 15s - loss: 0.7827 - acc: 0.7512 - val_loss: 1.2045 - val_acc: 0.6914
# Epoch 18/30
# Epoch 00017: val_loss did not improve
# 15s - loss: 0.7821 - acc: 0.7468 - val_loss: 0.9361 - val_acc: 0.7130
# Epoch 19/30
# Epoch 00018: val_loss did not improve
# 15s - loss: 0.7874 - acc: 0.7500 - val_loss: 0.8464 - val_acc: 0.7642
# Epoch 20/30
# Epoch 00019: val_loss did not improve
# 15s - loss: 0.7991 - acc: 0.7433 - val_loss: 1.1210 - val_acc: 0.7270
# Epoch 21/30
# Epoch 00020: val_loss did not improve
# 15s - loss: 0.8161 - acc: 0.7383 - val_loss: 0.8268 - val_acc: 0.7306
# Epoch 22/30
# Epoch 00021: val_loss did not improve
# 15s - loss: 0.8049 - acc: 0.7439 - val_loss: 0.8842 - val_acc: 0.7220
# Epoch 23/30
# Epoch 00022: val_loss did not improve
# 15s - loss: 0.8213 - acc: 0.7394 - val_loss: 1.2770 - val_acc: 0.6962
# Epoch 24/30
# Epoch 00023: val_loss did not improve
# 15s - loss: 0.8270 - acc: 0.7393 - val_loss: 1.3042 - val_acc: 0.7190
# Epoch 25/30
# Epoch 00024: val_loss did not improve
# 15s - loss: 0.8279 - acc: 0.7348 - val_loss: 0.8809 - val_acc: 0.7476
# Epoch 26/30
# Epoch 00025: val_loss did not improve
# 15s - loss: 0.8461 - acc: 0.7307 - val_loss: 1.4849 - val_acc: 0.7012
# Epoch 27/30
# Epoch 00026: val_loss did not improve
# 15s - loss: 0.8492 - acc: 0.7276 - val_loss: 1.1588 - val_acc: 0.6552
# Epoch 28/30
# Epoch 00027: val_loss did not improve
# 15s - loss: 0.8606 - acc: 0.7308 - val_loss: 1.0909 - val_acc: 0.6756
# Epoch 29/30
# Epoch 00028: val_loss did not improve
# 15s - loss: 0.8752 - acc: 0.7220 - val_loss: 1.2440 - val_acc: 0.6732
# Epoch 30/30
# Epoch 00029: val_loss did not improve
# 15s - loss: 0.8706 - acc: 0.7236 - val_loss: 0.8607 - val_acc: 0.7200

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7626

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
